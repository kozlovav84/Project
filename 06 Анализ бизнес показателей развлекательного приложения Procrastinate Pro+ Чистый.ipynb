# %% [markdown]
# # Анализ бизнес показателей развлекательного приложения Procrastinate Pro+

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Анализ-бизнес-показателей-развлекательного-приложения-Procrastinate-Pro+" data-toc-modified-id="Анализ-бизнес-показателей-развлекательного-приложения-Procrastinate-Pro+-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Анализ бизнес показателей развлекательного приложения Procrastinate Pro+</a></span></li><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Импортируем-необходимые-библиотеки" data-toc-modified-id="Импортируем-необходимые-библиотеки-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Импортируем необходимые библиотеки</a></span></li><li><span><a href="#Шаг-1.-Загружаем-данные-и-готовим-их-к-анализу" data-toc-modified-id="Шаг-1.-Загружаем-данные-и-готовим-их-к-анализу-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Шаг 1. Загружаем данные и готовим их к анализу</a></span><ul class="toc-item"><li><span><a href="#Таблица-visits" data-toc-modified-id="Таблица-visits-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Таблица <code>visits</code></a></span></li><li><span><a href="#Таблица-orders" data-toc-modified-id="Таблица-orders-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Таблица <code>orders</code></a></span></li><li><span><a href="#Таблица-costs" data-toc-modified-id="Таблица-costs-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Таблица <code>costs</code></a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Предобработка-visits" data-toc-modified-id="Предобработка-visits-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>Предобработка <code>visits</code></a></span></li><li><span><a href="#Предобработка-orders" data-toc-modified-id="Предобработка-orders-5.4.2"><span class="toc-item-num">5.4.2&nbsp;&nbsp;</span>Предобработка <code>orders</code></a></span></li><li><span><a href="#Предобработка-costs" data-toc-modified-id="Предобработка-costs-5.4.3"><span class="toc-item-num">5.4.3&nbsp;&nbsp;</span>Предобработка <code>costs</code></a></span></li></ul></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Шаг-2.-Задайте-функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Шаг-2.-Задайте-функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Шаг 2. Задайте функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Функции-для-LTV-и-ROI" data-toc-modified-id="Функции-для-LTV-и-ROI-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Функции для LTV и ROI</a></span></li><li><span><a href="#Функция-для-удержания" data-toc-modified-id="Функция-для-удержания-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Функция для удержания</a></span></li><li><span><a href="#Фунцция-для-расчёта-конверсии" data-toc-modified-id="Фунцция-для-расчёта-конверсии-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Фунцция для расчёта конверсии</a></span></li><li><span><a href="#Функции-визуализации" data-toc-modified-id="Функции-визуализации-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Функции визуализации</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Шаг-3.-Проведите-исследовательский-анализ-данных" data-toc-modified-id="Шаг-3.-Проведите-исследовательский-анализ-данных-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Шаг 3. Проведите исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Профили-пользователей" data-toc-modified-id="Профили-пользователей-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Профили пользователей</a></span></li><li><span><a href="#Минимальная-и-максимальная-дата-привлечения-пользователей" data-toc-modified-id="Минимальная-и-максимальная-дата-привлечения-пользователей-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Минимальная и максимальная дата привлечения пользователей</a></span></li><li><span><a href="#Страны,-из-которых-приходят-посетители.-Страны,-дающие-больше-всего-платящих-пользователей" data-toc-modified-id="Страны,-из-которых-приходят-посетители.-Страны,-дающие-больше-всего-платящих-пользователей-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Страны, из которых приходят посетители. Страны, дающие больше всего платящих пользователей</a></span></li><li><span><a href="#Устройства-пользователей.-Устройства-с-которых-чаще-всего-заходят-платящие-пользователи" data-toc-modified-id="Устройства-пользователей.-Устройства-с-которых-чаще-всего-заходят-платящие-пользователи-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Устройства пользователей. Устройства с которых чаще всего заходят платящие пользователи</a></span></li><li><span><a href="#Рекламные-каналы-привлечения-пользователей.-Каналы-приносящие-больше-всего-платящих-пользователей" data-toc-modified-id="Рекламные-каналы-привлечения-пользователей.-Каналы-приносящие-больше-всего-платящих-пользователей-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Рекламные каналы привлечения пользователей. Каналы приносящие больше всего платящих пользователей</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-7.6"><span class="toc-item-num">7.6&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Шаг-4.-Маркетинг" data-toc-modified-id="Шаг-4.-Маркетинг-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Шаг 4. Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Сумма-расходов-на-марктинг" data-toc-modified-id="Сумма-расходов-на-марктинг-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Сумма расходов на марктинг</a></span></li><li><span><a href="#Распределение-трат-по-источникам.-Визуализация-изменения-метрик-во-времени" data-toc-modified-id="Распределение-трат-по-источникам.-Визуализация-изменения-метрик-во-времени-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Распределение трат по источникам. Визуализация изменения метрик во времени</a></span></li><li><span><a href="#Цена-привлечения-одного-пользователя-из-каждого-источника" data-toc-modified-id="Цена-привлечения-одного-пользователя-из-каждого-источника-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Цена привлечения одного пользователя из каждого источника</a></span></li><li><span><a href="#Расчёт-средней-стоимости-привдечения-пользователя-для-всего-проекта" data-toc-modified-id="Расчёт-средней-стоимости-привдечения-пользователя-для-всего-проекта-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>Расчёт средней стоимости привдечения пользователя для всего проекта</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-8.5"><span class="toc-item-num">8.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Шаг-5.-Оценка-окупаемости-рекламы-для-привлечения-пользователей" data-toc-modified-id="Шаг-5.-Оценка-окупаемости-рекламы-для-привлечения-пользователей-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Шаг 5. Оценка окупаемости рекламы для привлечения пользователей</a></span><ul class="toc-item"><li><span><a href="#Анализ-общей-окупаемости-рекламы" data-toc-modified-id="Анализ-общей-окупаемости-рекламы-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Анализ общей окупаемости рекламы</a></span></li><li><span><a href="#Выводы:" data-toc-modified-id="Выводы:-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Выводы:</a></span><ul class="toc-item"><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам-9.2.1"><span class="toc-item-num">9.2.1&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по устройствам</a></span></li></ul></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Вывод:</a></span><ul class="toc-item"><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-странам-9.3.1"><span class="toc-item-num">9.3.1&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по странам</a></span></li></ul></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>Вывод:</a></span><ul class="toc-item"><li><span><a href="#Анализ-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Анализ-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам-9.4.1"><span class="toc-item-num">9.4.1&nbsp;&nbsp;</span>Анализ окупаемость рекламы с разбивкой по рекламным каналам</a></span></li></ul></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-9.5"><span class="toc-item-num">9.5&nbsp;&nbsp;</span>Вывод:</a></span></li><li><span><a href="#Графики-конверсии-и-удержания-с-разбивкой-по-устройствам,-странам,-рекламным-каналам" data-toc-modified-id="Графики-конверсии-и-удержания-с-разбивкой-по-устройствам,-странам,-рекламным-каналам-9.6"><span class="toc-item-num">9.6&nbsp;&nbsp;</span>Графики конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам</a></span><ul class="toc-item"><li><span><a href="#Конверсия-с-разбивкой-по-устройствам" data-toc-modified-id="Конверсия-с-разбивкой-по-устройствам-9.6.1"><span class="toc-item-num">9.6.1&nbsp;&nbsp;</span>Конверсия с разбивкой по устройствам</a></span></li><li><span><a href="#Удержание-с-разбивкой-по-устройствам" data-toc-modified-id="Удержание-с-разбивкой-по-устройствам-9.6.2"><span class="toc-item-num">9.6.2&nbsp;&nbsp;</span>Удержание с разбивкой по устройствам</a></span></li><li><span><a href="#Конверсия-с-разбивкой-по-странам" data-toc-modified-id="Конверсия-с-разбивкой-по-странам-9.6.3"><span class="toc-item-num">9.6.3&nbsp;&nbsp;</span>Конверсия с разбивкой по странам</a></span></li><li><span><a href="#Удержание-с-разбивкой-по-странам" data-toc-modified-id="Удержание-с-разбивкой-по-странам-9.6.4"><span class="toc-item-num">9.6.4&nbsp;&nbsp;</span>Удержание с разбивкой по странам</a></span></li><li><span><a href="#Конверсия-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Конверсия-с-разбивкой-по-рекламным-каналам-9.6.5"><span class="toc-item-num">9.6.5&nbsp;&nbsp;</span>Конверсия с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Удержание-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Удержание-с-разбивкой-по-рекламным-каналам-9.6.6"><span class="toc-item-num">9.6.6&nbsp;&nbsp;</span>Удержание с разбивкой по рекламным каналам</a></span></li></ul></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-9.7"><span class="toc-item-num">9.7&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Шаг-6.-Выводы" data-toc-modified-id="Шаг-6.-Выводы-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Шаг 6. Выводы</a></span></li></ul></div>

# %% [markdown]
# # Описание проекта
#
# Я - маркетинговый аналитик развлекательного приложения Procrastinate Pro+. Несколько прошлых месяцев наш бизнес постоянно нес убытки - в привлечение пользователей была вложена куча денег, а толку никакого. Нам нужно разобраться в причинах этой ситуации.
#
# У нас в распоряжении есть лог сервера с данными о посещениях приложения новыми пользователями, зарегистрировавшимися в период с 2019-05-01 по 2019-10-27, выгрузка их покупок за этот период, а также статистика рекламных расходов.
#
# Нам предстоит изучить:
# - как люди пользуются продуктом;
# - когда они начинают покупать;
# - сколько денег приносит каждый клиент;
# - когда он окупается;
# - какие факторы отрицательно влияют на привлечение пользователей.

# %% [markdown]
# # Описание данных
#
# Таблица `visits_log_short` (лог сервера с информацией о посещениях сайта):
#
#     User Id — уникальный идентификатор пользователя
#     Device — категория устройства пользователя
#     Session start — дата и время начала сессии
#     Session End — дата и время окончания сессии
#     Channel — идентификатор рекламного источника, из которого пришел пользователь
#     Region - страна пользователя
#
# `Таблица orders_log_short` (информация о заказах):
#
#     User Id — уникальный id пользователя, который сделал заказ
#     Event Dt — дата и время покупки
#     Revenue — выручка
#
# `Таблица costs_short` (информация о затратах на маркетинг):
#
#     Channel — идентификатор рекламного источника
#     Dt — дата
#     Costs — затраты на этот рекламный источник в этот день

# %% [markdown]
# # Импортируем необходимые библиотеки

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

# %% [markdown]
# # Шаг 1. Загружаем данные и готовим их к анализу
#
# В рамках данного раздела мы загрузим данные о визитах, заказах и расходах и поместим их в переменные, оптимизируем данные для анализа,  убедимся, что тип данных в каждой колонке — правильный.

# %%
try:
    visits = pd.read_csv('/datasets/visits_info_short.csv') #информация о посещениях
    orders = pd.read_csv('/datasets/orders_info_short.csv') #информация о заказах 
    costs = pd.read_csv('/datasets/costs_info_short.csv') #информация о затратах на маркетинг
except: 
    visits = pd.read_csv('visits_info_short.csv') #информация о посещениях
    orders = pd.read_csv('orders_info_short.csv') #информация о заказах 
    costs = pd.read_csv('costs_info_short.csv') #информация о затратах на маркетинг

# %% [markdown]
# Для знакомства с данными напишем функцию step_1

# %%
def step_1 (data):
    
    print ()# я люблю, чтобы между ячейкой ввода и ячейкой вывода было побольше места, поэтому добавляю print сверху и снизу 
    display (data.head())
    print ()
    print ('=' * 72) # так я делаю разделение, чтобы тебе, мой дорогой друг, было удобнее читать всё это безобразие
    print ()
    data.info()
    print ()
    print ('=' * 72)
    print ()
    print ('Количество неявных дубликатов:', data.duplicated().sum()) #проверяем на наличие явных дубликатов
    print ()

# %% [markdown]
# ## Таблица `visits`

# %% [markdown]
# Вызовем нашу функцию:

# %%
step_1 (visits)
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
# ...
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
# ...

# %% [markdown]
# Мы видим, что в таблице названия столбцов не соответствуют "змеиному регистру". А так же видим, что тип данных в столбцах `visits['Session Start', 'Session End']` крайней степени необходимо привести к формату `datetime`. Количество строк во всех столбцах одинаковое, значит пропусков нет, так же как и явных дубликатов.

# %% [markdown]
# ## Таблица `orders`

# %% [markdown]
# Вызываем функцию:

# %%
step_1 (orders)
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
# ...
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
#
# ...
#
# Количество неявных дубликатов: 0

# %% [markdown]
# Как и в предыдущей таблице  названия столбцов не соответствуют "змеиному регистру",  что тип данных в столбце `orders['Event Dt']` нужно срочно привести к формату `datetime`, иначе беда. Количество строк во всех столбцах одинаковое, значит пропусков нет, так же как и явных дубликатов.

# %% [markdown]
# ## Таблица `costs`

# %% [markdown]
# Вызываем функцию:

# %%
step_1(costs)
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1
# ...
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB
#
# ...
#
# Количество неявных дубликатов: 0

# %% [markdown]
# Видимо работающий в нашей компании датаинженер ничего не слышал, про то, как надо называть столбцы, надо бы ему рассказать. Недочёты те же, что и раньше: регистр (но не везде, только в `costs['Channel']`), `costs['dt']` и нужно срочно привести к формату `datetime`. Хорошо, что дубликатов и пропусков нет.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Предобработка `visits`

# %% [markdown]
# Приведём названия столбцов и типы данных к требуемым:

# %%
visits.columns = [x.lower().replace(' ', '_') for x in visits.columns.values] #приводим названия к змеиному регистру
visits['session_start'] = pd.to_datetime(visits['session_start']) # изменяем тип данных
visits['session_end'] = pd.to_datetime(visits['session_end'])

# %% [markdown]
# Проверяем, что получилось:

# %%
step_1(visits)
# Out:
#         user_id         region   device  channel       session_start  \
# 0  981449118918  United States   iPhone  organic 2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic 2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic 2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop 2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic 2019-05-01 03:33:35
#
#           session_end
# 0 2019-05-01 02:45:01
# 1 2019-05-01 04:47:35
# 2 2019-05-01 15:32:08
# 3 2019-05-01 00:54:25
# 4 2019-05-01 03:57:40
# ...
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
# ...

# %% [markdown]
# Божественно! Переходим к следующей таблице

# %% [markdown]
# ### Предобработка `orders`

# %% [markdown]
# С таблицей `orders` проведём похожии манипуляции:

# %%
orders.columns = [x.lower().replace(' ', '_') for x in orders.columns.values] #приводим названия к змеиному регистру
orders['event_dt'] = pd.to_datetime(orders['event_dt']) # изменяем тип данных

# %% [markdown]
# Проверяем:

# %%
step_1(orders)
# Out:
#         user_id            event_dt  revenue
# 0  188246423999 2019-05-01 23:09:52     4.99
# 1  174361394180 2019-05-01 12:24:04     4.99
# 2  529610067795 2019-05-01 11:34:04     4.99
# 3  319939546352 2019-05-01 15:34:40     4.99
# 4  366000285810 2019-05-01 13:59:51     4.99
# ...
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB
#
# ...
#
# Количество неявных дубликатов: 0

# %% [markdown]
# В очередной раз всё получилось, переходим к следующей таблице:

# %% [markdown]
# ### Предобработка `costs`

# %%
costs = costs.rename(columns={'Channel': 'channel'}) # ещё такой способ знаю
costs['dt'] = pd.to_datetime(costs['dt']) # изменяем тип данных

# %% [markdown]
# Проверяем:

# %%
step_1(costs)
# Out:
#           dt   channel  costs
# 0 2019-05-01  FaceBoom  113.3
# 1 2019-05-02  FaceBoom   78.1
# 2 2019-05-03  FaceBoom   85.8
# 3 2019-05-04  FaceBoom  136.4
# 4 2019-05-05  FaceBoom  122.1
# ...
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   datetime64[ns]
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 42.3+ KB
#
# ...
#
# Количество неявных дубликатов: 0

# %% [markdown]
# ## Вывод:

# %% [markdown]
# В рамках раздела мы загрузили данные, ознакомились с ними, проверили данные на наличие дубликатов, навели порядок в названих столбцов, а так же привели типы данных к нужным.

# %% [markdown]
# # Шаг 2. Задайте функции для расчета и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# ## Функции для LTV и ROI

# %% [markdown]
# Зададим функции для LTV и ROI `get_ltv()`

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ## Функция для удержания

# %% [markdown]
# Зададим функцию для удержания `get_retention()`

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ## Фунцция для расчёта конверсии

# %% [markdown]
# Зададим функцию для расчёта конверсии `get_conversion()`

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ## Функции визуализации

# %% [markdown]
# Зададим функции для визуализации метрик — `filter_data()`, `plot_retention()`, `plot_conversion()` и `plot_ltv_roi()`

# %%
# функция для сглаживания

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Вывод:

# %% [markdown]
# В текущем разделе мы задали  функции для расчета и анализа LTV, ROI `get_ltv()`, удержания `get_retention()` и конверсии `get_conversion()`. Дополнительно задали функции визуализации: функция для сглаживания `filter_data()`, визуализации удержания `plot_retention()`, визуализации конверсии `plot_conversion()`, визуализации LTV и ROI `plot_ltv_roi()`.

# %% [markdown]
# # Шаг 3. Проведите исследовательский анализ данных

# %% [markdown]
# В рамках раздела мы построим профили пользователей. Определим минимальную и максимальную дату привлечения пользователей, а так же выясним:
# - Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?
# - Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?
# - По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?

# %% [markdown]
# ## Профили пользователей

# %% [markdown]
# Напишем функции для создания пользовательских профилей:

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['dt'] = pd.to_datetime(profiles['dt'], format="%Y-%m-%d")
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())


    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# Получим профили пользователей. Для этого вызовем функцию get_profiles(), передав ей данные о посещениях, покупках и тратах на рекламу «Procrastinate Pro+».

# %%
profiles = get_profiles(visits, orders, costs)
profiles.head(5)
# Out:
#     user_id            first_ts     channel  device         region         dt  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States 2019-05-07
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States 2019-07-09
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France 2019-10-01
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany 2019-08-22
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States 2019-10-02
#
#        month  payer  acquisition_cost
# 0 2019-05-01   True          1.088172
# 1 2019-07-01  False          1.107237
# 2 2019-10-01  False          0.000000
# 3 2019-08-01  False          0.988235
# 4 2019-10-01  False          0.230769

# %% [markdown]
# ## Минимальная и максимальная дата привлечения пользователей

# %% [markdown]
# Определим минимальную и максимальную дату привлечения пользователей.

# %%
print ()
print ('Минимальная дата привлечения пользователей', profiles['first_ts'].min())
print ()
print ('Максимальная дата привлечения пользователей', profiles['first_ts'].max())
print ()
# Out:
# Минимальная дата привлечения пользователей 2019-05-01 00:00:41
#
# Максимальная дата привлечения пользователей 2019-10-27 23:59:04

# %% [markdown]
# ## Страны, из которых приходят посетители. Страны, дающие больше всего платящих пользователей

# %% [markdown]
# Для ответа на этот вопрос сгруппируем данные в сводную таблицу

# %%
report = profiles.groupby('region').agg({'user_id': 'nunique', 'payer': ['sum', 'mean']})
report.columns = ['Пользователи', 'Платящие пользователи', '% платящих']
report.sort_values(by= 'Пользователи', ascending = False).style.format({'ПЛатящие пользователи': '{:.0f}',
                                                                       '% платящих': '{:.2%}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_59e59980_ec21_11ec_939a_351c6216a8ec" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Пользователи</th>        <th class="col_heading level0 col1" >Платящие пользователи</th>        <th class="col_heading level0 col2" >% платящих</th>    </tr>    <tr>        <th class="index_name level0" >region</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_59e59980_ec21_11ec_939a_351c6216a8eclevel0_row0" class="row_heading level0 row0" >United States</th>
#                         <td id="T_59e59980_ec21_11ec_939a_351c6216a8ecrow0_col0" class="data row0 col0" >100002</td>
#                         <td id="T_59e59980_ec21_11ec_939a_351c6216a8ecrow0_col1" class="data row0 col1" >6902.000000</td>
# ...

# %% [markdown]
# Больше всего платящих пользователей приходит из США, что не удивительно.

# %% [markdown]
# ## Устройства пользователей. Устройства с которых чаще всего заходят платящие пользователи

# %% [markdown]
# Для ответа на этот вопрос также сгруппируем данные в сводную таблицу

# %%
report_device = profiles.groupby('device').agg({'user_id': 'nunique', 'payer': ['sum', 'mean']})
report_device.columns = ['Пользователи', 'Платящие пользователи', '% платящих']
report_device.sort_values(by= 'Пользователи', ascending = False).style.format({'ПЛатящие пользователи': '{:.0f}',
                                                                       '% платящих': '{:.2%}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_59f2b3ae_ec21_11ec_939a_351c6216a8ec" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Пользователи</th>        <th class="col_heading level0 col1" >Платящие пользователи</th>        <th class="col_heading level0 col2" >% платящих</th>    </tr>    <tr>        <th class="index_name level0" >device</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_59f2b3ae_ec21_11ec_939a_351c6216a8eclevel0_row0" class="row_heading level0 row0" >iPhone</th>
#                         <td id="T_59f2b3ae_ec21_11ec_939a_351c6216a8ecrow0_col0" class="data row0 col0" >54479</td>
#                         <td id="T_59f2b3ae_ec21_11ec_939a_351c6216a8ecrow0_col1" class="data row0 col1" >3382.000000</td>
# ...

# %% [markdown]
# Чаще всего платящие пользователи заходят с Mac, что тоже не удивительно

# %% [markdown]
# ## Рекламные каналы привлечения пользователей. Каналы приносящие больше всего платящих пользователей

# %% [markdown]
# Для ответа на этот вопрос ещё раз сгруппируем данные в сводную таблицу

# %%
report_channel = profiles.groupby('channel').agg({'user_id': 'nunique', 'payer': ['sum', 'mean']})
report_channel.columns = ['Пользователи', 'Платящие пользователи', '% платящих']
report_channel.sort_values(by= 'Пользователи', ascending = False).style.format({'ПЛатящие пользователи': '{:.0f}',
                                                                       '% платящих': '{:.2%}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_59ff00c8_ec21_11ec_939a_351c6216a8ec" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Пользователи</th>        <th class="col_heading level0 col1" >Платящие пользователи</th>        <th class="col_heading level0 col2" >% платящих</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_59ff00c8_ec21_11ec_939a_351c6216a8eclevel0_row0" class="row_heading level0 row0" >organic</th>
#                         <td id="T_59ff00c8_ec21_11ec_939a_351c6216a8ecrow0_col0" class="data row0 col0" >56439</td>
#                         <td id="T_59ff00c8_ec21_11ec_939a_351c6216a8ecrow0_col1" class="data row0 col1" >1160.000000</td>
# ...

# %% [markdown]
# Больше всего людей приходит из organic (назвать его бесплатным язык не поворачивается, так как правильно построенное SEO та ещё задача). Но платящих пользователей больше всего приходит из канала FaceBoom.

# %% [markdown]
# ## Вывод:
# В рамках данного раздела мы построили профили пользователей, определили минимальную и максимальную дату привлечения пользователей, выяснили, из каких стран приходят посетители,  какие страны дают больше всего платящих пользователей,
# узнали какими устройствами пользуются посетители, с  каких устройств чаще всего заходят платящие пользователи, а так же
# мы теперь знаем, по каким рекламным каналам шло привлечение пользователей и  какие каналы приносят больше всего платящих пользователей.

# %% [markdown]
# # Шаг 4. Маркетинг

# %% [markdown]
# В рамках текущего раздела мы выясним:
# - Сколько денег потратили? Всего / на каждый источник / по времени
# - Сколько в среднем стоило привлечение одного покупателя из каждого источника?

# %% [markdown]
# Посчитаем общую сумму расходов на маркетинг. Выясним, как траты распределены по источникам. Визуализируем изменения метрик во времени.

# %% [markdown]
# ## Сумма расходов на марктинг

# %% [markdown]
# Выясним общую сумму расходов на маркетинг

# %%
print ('Общая сумма расходов на маркетинг:', profiles['acquisition_cost'].sum().round(2)) 
#после точки было многоцифр (105497.29999999999) , я округлил для наглядности
# Out:
# Общая сумма расходов на маркетинг: 105497.3

# %% [markdown]
# Проведём группировку по каналам привлечения и агрегируем общую сумму по каждому из этих каналов

# %%
report_cost = profiles.groupby('channel').agg({'acquisition_cost': ['sum']})
report_cost.columns = ['сумма расходов']
report_cost.sort_values(by= 'сумма расходов', ascending = False).style.format({'сумма расходов': '{:.0f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_5a09af8c_ec21_11ec_939a_351c6216a8ec" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >сумма расходов</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5a09af8c_ec21_11ec_939a_351c6216a8eclevel0_row0" class="row_heading level0 row0" >TipTop</th>
#                         <td id="T_5a09af8c_ec21_11ec_939a_351c6216a8ecrow0_col0" class="data row0 col0" >54751</td>
#             </tr>
#             <tr>
#                         <th id="T_5a09af8c_ec21_11ec_939a_351c6216a8eclevel0_row1" class="row_heading level0 row1" >FaceBoom</th>
#                         <td id="T_5a09af8c_ec21_11ec_939a_351c6216a8ecrow1_col0" class="data row1 col0" >32446</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# Больше всего вложений в сети:
# - `TipTop`
# - `FaceBoom`

# %% [markdown]
# ## Распределение трат по источникам. Визуализация изменения метрик во времени

# %% [markdown]
# Построим сводную таблицу с датами в строках, каналами в столбцах и суммой расходов на пересечении

# %%
changing_metrics = costs.pivot_table(index='dt', columns='channel', values='costs', aggfunc='sum')
changing_metrics.head()
# Out:
# channel     AdNonSense  FaceBoom  LeapBob  MediaTornado  OppleCreativeMedia  \
# dt
# 2019-05-01       40.95     113.3     2.52          6.24                4.25
# 2019-05-02       34.65      78.1     2.94          5.04                4.25
# 2019-05-03       47.25      85.8     2.73          6.96                5.75
# 2019-05-04       51.45     136.4     3.99          9.36                4.25
# 2019-05-05       36.75     122.1     4.62         11.04                5.50
#
# channel     RocketSuperAds  TipTop  WahooNetBanner  YRabbit  lambdaMediaAds
# dt
# 2019-05-01          21.060    80.0            10.8      8.1            17.6
# 2019-05-02          16.965    55.0             7.2      9.9            16.8
# 2019-05-03          16.380    64.0             8.4      9.0            16.8
# 2019-05-04          17.550    70.0            10.8     15.6            17.6
# 2019-05-05          27.495    78.0            12.0      9.6            12.8

# %% [markdown]
# Изучим динамики маркетинговых затрат за весь изучаемый период

# %%
profiles.pivot_table(index='month', values='acquisition_cost', aggfunc='sum').plot(grid=True, figsize=(20, 10))
plt.title("Расходы помесячно",fontsize=15)
plt.xlabel("Месяцы",fontsize=10)
plt.ylabel("Расходы",fontsize=10)
plt.show()

# %% [markdown]
# С каждым месяцем вложения в рекламу только увеличиваются. Поскольку максимальная дата 27 октября, то а разница с сентябрём не велика, то можно считать, что траты в октябре и сентябре равны. К тому же за 4 дня есть все шансы реально "догнать" сентябрь.

# %% [markdown]
# Изучим динамики маркетинговых затрат по каналам по месяцам

# %%
profiles.pivot_table(index='month', columns='channel', values='acquisition_cost', aggfunc='sum'
                                    ).plot(grid=True, figsize=(20, 10))
plt.title("Количествово затрат по месяцам",fontsize=30)
plt.xlabel("Месяц",fontsize=20)
plt.ylabel("Количествово затрат",fontsize=20)
plt.show()

# %% [markdown]
# Для более подробного изучения, посмотрим, как распределялись траты на каналы привлечения по дням за весь изучаемый период

# %%
profiles.pivot_table(index='dt', columns='channel', values='acquisition_cost', aggfunc='sum'
                                    ).plot(grid=True, figsize=(20, 10))
plt.title("Количествово затрат по дням",fontsize=30)
plt.xlabel("Дни",fontsize=20)
plt.ylabel("Количествово затрат",fontsize=20)
plt.show()

# %% [markdown]
# `TipTop` обогатился за счёт `Procrastinate Pro+` и является явным лидером по вложениям. Мало того, вложения в эту сеть регулярно растут

# %% [markdown]
# ## Цена привлечения одного пользователя из каждого источника

# %% [markdown]
# Построим сводную таблицу и узнаем средний САС для каждого источника по месяцам

# %%
cac_cost = profiles.pivot_table(index='channel', columns='month', values='acquisition_cost', aggfunc='mean')
cac_cost
# Out:
# month               2019-05-01  2019-06-01  2019-07-01  2019-08-01  \
# channel
# AdNonSense            1.027856    1.012500    0.992126    0.995876
# FaceBoom              1.105868    1.116748    1.113652    1.112088
# LeapBob               0.201842    0.211696    0.209859    0.210478
# MediaTornado          0.226768    0.218354    0.215365    0.224325
# OppleCreativeMedia    0.243544    0.249831    0.251544    0.250142
# RocketSuperAds        0.549411    0.498798    0.417334    0.354000
# TipTop                1.357468    2.077684    2.650552    3.011290
# WahooNetBanner        0.577655    0.598441    0.607709    0.605941
# YRabbit               0.281144    0.182788    0.161493    0.191908
# lambdaMediaAds        0.753947    0.732353    0.721053    0.694006
# organic               0.000000    0.000000    0.000000    0.000000
#
# month               2019-09-01  2019-10-01
# channel
# AdNonSense            1.004663    0.993715
# FaceBoom              1.114434    1.114316
# ...

# %% [markdown]
# Построим график динамики САС по каналам привлечения

# %%
profiles.pivot_table(
    index='dt', columns='channel', values='acquisition_cost', aggfunc='mean'
).plot(grid=True, figsize=(20, 10))
plt.ylabel('CAC', fontsize=20)
plt.xlabel('Дата привлечения', fontsize=20)
plt.title('Динамика САС по каналам привлечения', fontsize=30)
plt.show()

# %% [markdown]
# Самый дорогой пользователь приходит из `TipTop`, причём цена его постоянно растёт. Если в мае цена его была 1,36, то к октябрю цена вырасла более чем в 2 раза и составила 3,54. Цены пользователей остальных каналов относительно стабильны.

# %%
temp = profiles.groupby('channel').agg({'acquisition_cost':'mean'}).sort_values(
    by= 'acquisition_cost', ascending = False).round(2)#.plot(kind='bar', grid=True, figsize=(20, 10))
display (temp)
print ()
print ('*'* 110)
print
temp.plot(kind='bar', grid=True, figsize=(20, 10))
plt.ylabel('САС', fontsize=20)
plt.xlabel('Канал привлечения', fontsize=20)
plt.title('Средняя CAC клиента по каналам', fontsize=30)
# Out:
#                     acquisition_cost
# channel
# TipTop                          2.80
# FaceBoom                        1.11
# AdNonSense                      1.01
# lambdaMediaAds                  0.72
# WahooNetBanner                  0.60
# RocketSuperAds                  0.41
# OppleCreativeMedia              0.25
# YRabbit                         0.22
# MediaTornado                    0.22
# LeapBob                         0.21
# organic                         0.00
# **************************************************************************************************************
# Text(0.5, 1.0, 'Средняя CAC клиента по каналам')

# %% [markdown]
# Как и предполагалось ранее, самый дорогой пользователь приходит из `TipTop` и в среднем обходится в 2.80 у.е. `FaceBoom` и `AdNonSense` стоят около 1 у. е. Остальные в среднем менее 1 у.е.

# %% [markdown]
# ## Расчёт средней стоимости привдечения пользователя для всего проекта

# %% [markdown]
# Для расчёта САС для всего проекта возьмём среднее расходов `acquisition_cost` по всем каналам, кроме `organic`, из таблицы профилей пользователей `profiles`.

# %%
print ()
print ('Cредний CAC на одного пользователя для всего проекта равен',\
profiles.query('channel != "organic"')['acquisition_cost'].mean(), 'у.е.')
print ()
# Out:
# Cредний CAC на одного пользователя для всего проекта равен 1.127481323942928 у.е.

# %% [markdown]
# ## Вывод

# %% [markdown]
# На данном этапе мы посчитали общую сумму расходов на маркетинг, выяснили как траты распределены по источникам и визуализировали изменения метрик во времени.
#
# Проанализировав график динамики САС по кналам привлечения, заметили, что все каналы кроме TipTop по динамике относительно стабильны. За всё время привлечения, динамика САС по каналу TipTop растёт от 1,36 у.е до 3,54 у.е.
#
# Самыми дорогими пользователями по САС являются:
# - `TipTop` - 2.8 у.е.;
# - `FaceBoom` - 1.11 у.е;
# - `AdNonSense` - 1.01 у.е.

# %% [markdown]
# # Шаг 5. Оценка окупаемости рекламы для привлечения пользователей
#
# В текущем разделе мы
# С помощью LTV и ROI:
# - проанализируем общую окупаемость рекламы;
# - проанализируем окупаемость рекламы с разбивкой по устройствам;
# - проанализируем окупаемость рекламы с разбивкой по странам;
# - проанализируем окупаемость рекламы с разбивкой по рекламным каналам.
#
# Опишем проблемы, которые обнаружим, и  ответим на следующие вопросы:
# - Окупается ли реклама, направленная на привлечение пользователей в целом?
# - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# - Чем могут быть вызваны проблемы окупаемости? Изучите конверсию и удержание с разбивкой по устройствам, странам, рекламным каналам.
#
# Опишем возможные причины обнаруженных проблем и сформирем рекомендации для рекламного отдела.

# %% [markdown]
# ## Анализ общей окупаемости рекламы

# %% [markdown]
# Для начала установим момент и горизонт анализа данных. В условии сказано, `что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения`. Поэтому:

# %%
observation_date = datetime(2019, 11, 1).date() # момент анализа
horizon_days = 14 # горизонт анализа

# %% [markdown]
# Из расчетов нам следует исключить пользователей с органическим трафиком, поскольку  нам нужно изучить именно окупаемость именно рекламы.

# %%
profiles = profiles.query('channel != "organic"')

# %% [markdown]
# Оценим общую ситуацию — посмотрим на окупаемость рекламы. Рассчитаем и визуализируем LTV и ROI, вызвав функции `get_ltv()` и `plot_ltv_roi()`

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# ## Выводы:
#
# - Реклама полностью не окупается. ROI в конце двух недель — чуть более 80%.
# - LTV в динамике движется не стабильно. Линия поддержки на отметке 0.8, а линия сопротивления на отметке 1. Наблюдается боковой тренд.
# - Динамика стоимости привлечения "неумолимо" растёт, что говорит о растущих расходах рекламного бюджета.
# - Наблюдаем, что динамика ROI за лайфтайм падает. При относительно стабильной динамике LTV, динамика САС растёт с мая по конец октября. Эту закономерность мы наблюдаем в динамике ROI, что при сильном увеличении САС, в равной степени падает динамика ROI пользователей.
#
# - Общее ROI падаёт со временем. На сколько я помню ROI падать не должен, в идеале он должен стремиться к бесконечности. Настоящая ситуация вызвана увеличением расходов и неокумаемостью затрат.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по устройствам

# %% [markdown]
# Посмотрим на окупаемость рекламы с разбивкой по устройствам

# %%
# смотрим окупаемость с разбивкой по устройствам

dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# ## Вывод:

# %% [markdown]
# Iphone, Mac и Android стабильно не окупается. А РС еле еле выше уровня окупаемости
# Так же наблюдаем, что динамика ROI падает относительно САС. Однако стоимость привлечения пользователей стабильно растёт. Скоро узнаем, в чём причина: в низкой конверсии или низком удержании.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по странам

# %% [markdown]
# Посмотрим на окупаемость рекламы с разбивкой по странам

# %%
# смотрим окупаемость с разбивкой по странам

dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# ## Вывод:
# Судя по графикам,  в отличии от France, Germany и UK, United States не отбивает вложенные инвестиции в рекламу. Каждые 2 недели наблюдаем нисходящую динамику ROI у United States. Дополнительно видим рост стоимости привлечения пользователей United States.

# %% [markdown]
# ### Анализ окупаемость рекламы с разбивкой по рекламным каналам

# %% [markdown]
# Посмотрим на окупаемость рекламы с разбивкой по рекламным каналам

# %%
# смотрим окупаемость с разбивкой по источникам привлечения

dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# ## Вывод:
#
# Окупаются все каналы привлечения кроме `TipTop`, `FaceBoom`, `AdNonSense`, что ожидаемо.
#
# Динамика стоимости привлечения пользователей для канала `TipTop` резко растёт, это было видно ещё на начальных этапах анализа. Наблюдаем цикличность: 2 недели растёт, 2 недели стабильна. Это плохо для бизнеса.
#
# Высока вероятность того, что проблема в `TipTop`
#
# Хорошо показала себя рекламная сеть `YRabbit`: в июле - ROI пользователей на 14 день был высок.

# %% [markdown]
# ## Графики конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам

# %% [markdown]
# ### Конверсия с разбивкой по устройствам

# %% [markdown]
# Посмотрим конверсию с разбивкой по устройствам

# %%
# смотрим конверсию с разбивкой по устройствам
dimensions = ['device']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Судя по графикам, пользователи Andriod, Mac, Iphone конвентируются очень хорошо. PC отстаёт, видимо пользователи РС не очень любят развлекаться.

# %% [markdown]
# ### Удержание с разбивкой по устройствам

# %% [markdown]
# Посмотрим удержание с разбивкой по устройствам

# %%
# смотрим удержание с разбивкой по устройствам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Удержание платящих пользователей выше, чем неплатящих. Так и должно быть

# %% [markdown]
# ### Конверсия с разбивкой по странам

# %% [markdown]
# Посмотрим конверсию с разбивкой по странам

# %%
# смотрим конверсию с разбивкой по странам
dimensions = ['region']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Для  United States то конверсия самая высокая. И динамика конверсии тоже. Дай угадаю, проблема в удержании.

# %% [markdown]
# ### Удержание с разбивкой по странам

# %% [markdown]
# Посмотрим удержание с разбивкой по странам

# %%
# смотрим удержание с разбивкой по странам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Так и есть, удержание для платящих пользователей United States отвратительно ужасное.

# %% [markdown]
# ### Конверсия с разбивкой по рекламным каналам

# %% [markdown]
#  Посмотрим конверсию с разбивкой по рекламным каналам

# %%
# смотрим конверсию с разбивкой по рекламным каналам
dimensions = ['channel']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Аномалий не обнаружено

# %% [markdown]
# ### Удержание с разбивкой по рекламным каналам

# %% [markdown]
# Посмотрим удержание с разбивкой по рекламным каналам

# %%
# смотрим удержание с разбивкой по рекламным каналам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Видим явных аутсайдеров - плохо удерживаются пользователи из каналов `FaceBoom` и `AdNonSense`.

# %% [markdown]
# ## Вывод:

# %% [markdown]
# В целом, реклама близка к окупемости. Если учитывать, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения, то есть вероятность, что реклама успеет окупиться.
# Окупаемость снижают владельцы Mac и iPhone, страна - United States. Не окупаются пользователи, привлеченные из каналов `LeapBop`, `FaceBoom`, `TipTop`, при этом большую часть вложений в рекламу идёт на `TipTop` и `FaceBoom`.
# Так же возможно, что горизонт анализа недостаточен для того, чтобы пользователи окупились. Можно взять 30 дней, и посмотреть, что будет.
# У США лучшая конверсия и очень слабое их удержание.
#
# Потенциал у платящих в США большой, только они привлекаются не по тем каналам

# %% [markdown]
# # Шаг 6. Выводы
# - Выделим причины неэффективности привлечения пользователей;
# - Сформируем рекомендации для отдела маркетинга для повышения эффективности.

# %% [markdown]
# В ходе выполнения проекта была проведена следующая работа:
# - загружены данные, подготовка их к анализу,  предобработка данных;
# - заданы функции для расчета и анализа LTV, ROI, удержания и конверсии;
# - Проведён исследовательский анализ данных;
# - Проведено маркетинговое исследование;
# - Проведена оценка окупаемости рекламы для привлечения пользователей;
# - Построены графики конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам.
#
# На основе проведённой работы можно сделать следующие выводы:
# 1. Общая сумма расходов на маркетинг: 105497.3 у.е.
# 2. Реклама полностью не окупается. ROI в конце двух недель — чуть более 80%.
# 3. Больше всего платящих пользователей приходит из США.
# 4. Для United States то конверсия самая высокая
# 5. Удержание для платящих пользователей United States отвратительно ужасное.
# 6. United States не окупают вложенные инвестиции в рекламу.
# 7. Чаще всего платящие пользователи заходят с Mac.
# 8. Пользователи устройств Iphone, Mac и Android стабильно не окупается.
# 9. Пользователи Andriod, Mac, Iphone конвентируются очень хорошо.
# 10. Больше всего людей приходит из `organic` однако они слабо конвертируются (2%).
# 11. Платящих пользователей больше всего приходит из канала FaceBoom.
# 12. Больше всего вложений в сети:
# - `TipTop`;
# - `FaceBoom`.
# 13. Окупаются все каналы привлечения кроме `TipTop`, `FaceBoom`, `AdNonSense`.
# 14. Самый дорогой пользователь приходит из `TipTop`, причём цена его постоянно растёт и в среднем обходится в 2.80 у.е.
# 15. Плохо удерживаются пользователи из каналов `FaceBoom` и `AdNonSense`.
# 16. Удержание платящих пользователей выше, чем неплатящих.
#
# Рекомендации для отдела маркетинга:
#
# 1. Разработать и реализовать комплекс мероприятий, направленный на увеличение конверсии из organic: за анализируемый период из канала  пришло 56439 пользователей (потенциальных клиентов), однако сконвертировалось всего 1160 (2.06%).
# 2. Разработать и реализовать комплекс мероприятий, направленный на удержание платящих пользователей из США: на 14-ый день около 10%, что является крайне низким отнсительно других стран. Возможно применить рассылки, пуш-уведомления, сообщения о промо акциях, уведомления о скидках и прочие мероприятия, направленные на увеличение удержания.
# 3. Перераспределить рекламный бюджет среди на `TipTop` и `FaceBoom` на другие каналы (например рекламная сеть `YRabbit` показывала хороший результат).
# 4. Разработать и реализовать комплекс мероприятий, направленный на удержание пользователей устройств Iphone, Mac и Android: при хорошей конверсии окупаемость страдает.
# 5. Разработать и реализовать комплекс мероприятий, направленный на привлечение большего количества клиентов из Germany и UK. Лучше всего окупаются пользователи из  Germany и UK. Возможно, стоит попробовать закупить больше трафика, целясь на эту аудиторию.
# 6. Пересмотреть рекламную политику для `TipTop`, `FaceBoom`, `AdNonSense`: собрать свежее семантическое ядро, пересмотреть целевые действия (показы, клики, целевые действия), регион показа, время показа и пол, возраст целевой аудитории.
# 7. Проверить компетентность лиц, отвечающих за настройку рекламы в сетях `TipTop`, `FaceBoom`, `AdNonSense`.
